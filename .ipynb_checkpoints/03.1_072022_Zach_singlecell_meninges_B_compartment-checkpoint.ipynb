# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import os
import tools

sc.logging.print_header()

os.chdir(os.path.expanduser('/home/jovyan/Zach/scanpy/'))
adata = sc.read_h5ad('h5ad/meninges_integrated.h5ad')
adata
# Out:
# scanpy==1.8.2 anndata==0.7.6 umap==0.5.1 numpy==1.21.6 scipy==1.5.2 pandas==1.3.5 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 leidenalg==0.8.2 pynndescent==0.5.2
# AnnData object with n_obs × n_vars = 11931 × 3239
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
bdata = adata[adata.obs['celltype'].isin(['B'])].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 522 × 3239
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
### recompute umap
bdata = bdata.raw.to_adata()
sc.pp.highly_variable_genes(bdata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(bdata)

# %%
bdata.raw = bdata

# %%
bdata = bdata[:, bdata.var.highly_variable].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 522 × 3551
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'

# %%
# sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt', 'S_score', 'G2M_score'])
sc.pp.regress_out(bdata, ['total_counts', 'pct_counts_mt'])
sc.pp.scale(bdata, max_value=10)

# %%
sc.tl.pca(bdata, svd_solver='arpack', n_comps=100)
sc.pl.pca_variance_ratio(bdata, log=True, n_pcs=100)

# %%
sc.external.pp.harmony_integrate(bdata, key = 'sequencing_batch', adjusted_basis='X_pca')
# Out:
# 2022-07-22 12:46:06,914 - harmonypy - INFO - Iteration 1 of 10
# 2022-07-22 12:46:07,299 - harmonypy - INFO - Iteration 2 of 10
# 2022-07-22 12:46:07,619 - harmonypy - INFO - Iteration 3 of 10
# 2022-07-22 12:46:08,012 - harmonypy - INFO - Iteration 4 of 10
# 2022-07-22 12:46:08,398 - harmonypy - INFO - Iteration 5 of 10
# 2022-07-22 12:46:08,619 - harmonypy - INFO - Converged after 5 iterations

# %%
sc.pl.pca_variance_ratio(bdata, log=True, n_pcs=100)

# %%
sc.pp.neighbors(bdata, n_neighbors=10, n_pcs = 60)
sc.tl.umap(bdata, min_dist=.3)

# %%
sc.pl.umap(bdata, color=['sequencing_batch', 'sample_id'])

# %%
sc.tl.leiden(bdata)
sc.pl.umap(bdata, color=['celltype', 'condition', 'leiden'])

# %%
sc.pl.umap(bdata, color = ['Cd19', 'Ms4a1', 'Cd79a', 'Il7r', 'Sox5', 'Cd3d', 'Cd27', 'Gpr183', 'Mki67', 'Ighm', 'Ighd'], color_map = tools.cmp(), ncols = 3)

# %%
sc.tl.embedding_density(bdata, groupby='condition')
bdata
# Out:
# AnnData object with n_obs × n_vars = 522 × 3551
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype', 'umap_density_condition'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap', 'sequencing_batch_colors', 'umap_density_condition_params'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.embedding_density(bdata, key = 'umap_density_condition', group = 'naive', color_map = 'Blues')
sc.pl.embedding_density(bdata, key = 'umap_density_condition', group = 'VSV', color_map = 'Reds')

# %%
sc.tl.rank_genes_groups(bdata, groupby = 'leiden', method = 'wilcoxon')

# %%
sc.pl.rank_genes_groups_dotplot(bdata, n_genes= 5, 
                                min_logfoldchange = 1, 
                                standard_scale = 'var', 
                                color_map = 'viridis', dendrogram = False)

# %%
sc.pl.dotplot(bdata, {
    'T':['Cd3d', 'Cd3e', 'Trac', 'Trbc1', 'Trbc2', 'Bcl6'],
    'Pro-B':['Il7r', 'Mki67', 'Igll1'],
    'B_developing':['Il7r', 'Dntt', 'Rag1', 'Cd34', 'Mki67'],
    'B_GC':['Aicda', 'Cd83', 'Cxcr4', 'Cd40', 'Irf4', 'Ms4a1', 'Cxcr5', 'Pax5', 'Sox5',  'Ccnd2', 'Myc', 'Foxo1', 'Tnfrsf13c'],
    'B_memory':['Cd27', 'Ccr6','Gpr183'],
    'Early PB':['Tnfrsf17', 'Mzb1', 'Jchain'],
    'isotype':['Ighm', 'Ighd', 'Igha', 'Ighg1', 'Ighg2b', 'Ighg3', 'Ighe']
},
              groupby = 'leiden',
              standard_scale = 'var', 
              color_map = 'Blues',)

# %%
new_dict ={'0':'B_GC',
'1':'B_GC',
'2':'B_developing',
'3':'B_GC',
'4':'B_developing',
'5':'B_GC',
'6':'B_GC',
'7':'B-T_multiplets',
}
bdata.obs['celltype'] = [new_dict[x] for x in bdata.obs['leiden']]
sc.pl.umap(bdata, color = ['leiden', 'celltype'])
# Out:
# /home/jovyan/my-conda-envs/dandelion/lib/python3.7/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'celltype' as categorical

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Cd83', 'Cd86', 'Fcgr2b'],
               'Developing':['Il7r', 'Cd93', 'Rag1', 'Dntt', 'Pax5'],
               'Follicle':['Cxcr5', 'Icosl', 'Gpr183', 'Ccr6'],
               'Germinal centre':['Cd40', 'Bach2', 'Myc', 'Ccnd2', 'Ccnd3', 'Cxcr4', 'Cd38', 'Mki67', 'Sox5', ],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3'],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17'],
               'other':['Cxcr3', 'Cd5', 'Cd27', 'Cxcl12', 'Cxcl13'],
               'Follicular T-cell':['Bcl6', 'Pdcd1', 'Cd3e', 'Cd40lg', 'Foxp3']
              }
              , groupby = 'leiden', color_map = 'GnBu', standard_scale = 'var', var_group_rotation = 0)

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Fcer2a', 'Cd24a', 'Cd86', 'Cd274', 'Fcgr2b'],
               'Developing':['Il7r', 'Cd93', 'Rag1', 'Dntt', 'Pax5'],
               'Follicle':['Cxcr5', 'Icosl', 'Gpr183', 'Ccr6'],
               'Germinal centre':['Cd83', 'Cxcr4', 'Cd38', 'Cd40', 'Sox5', 'Myc', 'Bach2', 'Ccnd2', 'Ccnd3', 'Mki67', ],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3',],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17',],
               'other':['Cxcr3', 'Cd5', 'Cd27',],
               'Follicular T-cell':['Bcl6', 'Pdcd1', 'Cd3e', 'Icos', 'Cd40lg', 'Foxp3', ]
              }
              , groupby = 'celltype', color_map = 'GnBu', standard_scale = 'var', var_group_rotation = 0)

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 522 × 3551
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype', 'umap_density_condition'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap', 'sequencing_batch_colors', 'umap_density_condition_params'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata.obs['celltype'] = adata.obs['celltype'].astype(str)
adata.obs['celltype'].update(bdata.obs['celltype'])

# %%
sc.pl.umap(adata, color = 'celltype')
# Out:
# /home/jovyan/my-conda-envs/dandelion/lib/python3.7/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'celltype' as categorical

# %%
# add the plasma blast

# %%
bdata = adata[adata.obs['celltype'].isin(['Plasma'])].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 137 × 3239
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
### recompute umap
bdata = bdata.raw.to_adata()
sc.pp.highly_variable_genes(bdata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(bdata)

# %%
bdata.raw = bdata

# %%
bdata = bdata[:, bdata.var.highly_variable].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 137 × 3042
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'

# %%
# sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt', 'S_score', 'G2M_score'])
sc.pp.regress_out(bdata, ['total_counts', 'pct_counts_mt'])
sc.pp.scale(bdata, max_value=10)

# %%
sc.tl.pca(bdata, svd_solver='arpack', n_comps=100)
sc.pl.pca_variance_ratio(bdata, log=True, n_pcs=100)

# %%
sc.external.pp.harmony_integrate(bdata, key = 'sequencing_batch', adjusted_basis='X_pca')
# Out:
# 2022-07-22 12:46:34,194 - harmonypy - INFO - Iteration 1 of 10
# 2022-07-22 12:46:34,238 - harmonypy - INFO - Iteration 2 of 10
# 2022-07-22 12:46:34,286 - harmonypy - INFO - Iteration 3 of 10
# 2022-07-22 12:46:34,335 - harmonypy - INFO - Iteration 4 of 10
# 2022-07-22 12:46:34,388 - harmonypy - INFO - Iteration 5 of 10
# 2022-07-22 12:46:34,436 - harmonypy - INFO - Converged after 5 iterations

# %%
sc.pp.neighbors(bdata, n_neighbors=10, n_pcs = 60)
sc.tl.umap(bdata, min_dist=.3)

# %%
sc.pl.umap(bdata, color=['sequencing_batch', 'sample_id'])

# %%
sc.tl.leiden(bdata)
sc.pl.umap(bdata, color=['celltype', 'condition', 'leiden'])

# %%
sc.pl.umap(bdata, color = ['Cd19', 'Ms4a1', 'Cd79a', 'Il7r', 'Sox5', 'Cd3d', 'Cd27', 'Gpr183', 'Mki67', 'Ighm', 'Ighd'], color_map = tools.cmp(), ncols = 3)

# %%
sc.tl.rank_genes_groups(bdata, groupby = 'leiden', method = 'wilcoxon')

# %%
sc.pl.rank_genes_groups_dotplot(bdata, n_genes= 5, 
                                min_logfoldchange = 1, 
                                standard_scale = 'var', 
                                color_map = 'viridis', dendrogram = False)

# %%
sc.pl.dotplot(bdata, {
    'T':['Cd3d', 'Cd3e', 'Trac', 'Trbc1', 'Trbc2', 'Bcl6'],
    'Pro-B':['Il7r', 'Mki67', 'Igll1'],
    'Plasma':['Cd19', 'Ptprc'],
    'B_developing':['Il7r', 'Dntt', 'Rag1', 'Cd34', 'Mki67'],
    'B_GC':['Aicda', 'Cd83', 'Cxcr4', 'Cd40', 'Irf4', 'Ms4a1', 'Cxcr5', 'Pax5', 'Sox5',  'Ccnd2', 'Myc', 'Foxo1', 'Tnfrsf13c'],
    'B_memory':['Cd27', 'Ccr6','Gpr183'],
    'Early PB':['Tnfrsf17', 'Mzb1', 'Jchain'],
    'isotype':['Ighm', 'Ighd', 'Igha', 'Ighg1', 'Ighg2b', 'Ighg3', 'Ighe']
},
              groupby = 'leiden',
              standard_scale = 'var', 
              color_map = 'Blues',)

# %%
new_dict ={'0':'B_Plasma',
'1':'B_Plasma',
'2':'B_Plasma',
'3':'B_Plasma',
'4':'B-T_multiplets',
'5':'B-T_multiplets',
}
bdata.obs['celltype'] = [new_dict[x] for x in bdata.obs['leiden']]
sc.pl.umap(bdata, color = ['leiden', 'celltype'])
# Out:
# /home/jovyan/my-conda-envs/dandelion/lib/python3.7/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'celltype' as categorical

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Cd83', 'Cd86', 'Fcgr2b'],
               'Developing':['Il7r', 'Cd93', 'Rag1', 'Dntt', 'Pax5'],
               'Follicle':['Cxcr5', 'Icosl', 'Gpr183', 'Ccr6'],
               'Germinal centre':['Cd40', 'Bach2', 'Myc', 'Ccnd2', 'Ccnd3', 'Cxcr4', 'Cd38', 'Mki67', 'Sox5', ],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3'],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17'],
               'other':['Cxcr3', 'Cd5', 'Cd27', 'Cxcl12', 'Cxcl13'],
               'Follicular T-cell':['Bcl6', 'Pdcd1', 'Cd3e', 'Cd40lg', 'Foxp3']
              }
              , groupby = 'leiden', color_map = 'GnBu', standard_scale = 'var', var_group_rotation = 0)

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Fcer2a', 'Cd24a', 'Cd86', 'Cd274', 'Fcgr2b'],
               'Developing':['Il7r', 'Cd93', 'Rag1', 'Dntt', 'Pax5'],
               'Follicle':['Cxcr5', 'Icosl', 'Gpr183', 'Ccr6'],
               'Germinal centre':['Cd83', 'Cxcr4', 'Cd38', 'Cd40', 'Sox5', 'Myc', 'Bach2', 'Ccnd2', 'Ccnd3', 'Mki67', ],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3',],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17',],
               'other':['Cxcr3', 'Cd5', 'Cd27',],
               'Follicular T-cell':['Bcl6', 'Pdcd1', 'Cd3e', 'Icos', 'Cd40lg', 'Foxp3', ]
              }
              , groupby = 'celltype', color_map = 'GnBu', standard_scale = 'var', var_group_rotation = 0)

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 137 × 3042
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap', 'sequencing_batch_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata.obs['celltype'] = adata.obs['celltype'].astype(str)
adata.obs['celltype'].update(bdata.obs['celltype'])

# %%
sc.pl.umap(adata, color = 'celltype')
# Out:
# /home/jovyan/my-conda-envs/dandelion/lib/python3.7/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'celltype' as categorical

# %%
## final check

# %%
bdata = adata[adata.obs['celltype'].isin(['B_Plasma', 'B_GC', 'B-T_multiplets', 'B_developing'])].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 659 × 3239
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
### recompute umap
bdata = bdata.raw.to_adata()
sc.pp.highly_variable_genes(bdata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(bdata)

# %%
bdata.raw = bdata

# %%
bdata = bdata[:, bdata.var.highly_variable].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 659 × 4289
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'S_score', 'G2M_score', 'phase', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP', 'leiden_R', 'celltype'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'celltype_colors', 'condition_colors', 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_R_colors', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'

# %%
# sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt', 'S_score', 'G2M_score'])
sc.pp.regress_out(bdata, ['total_counts', 'pct_counts_mt'])
sc.pp.scale(bdata, max_value=10)

# %%
sc.tl.pca(bdata, svd_solver='arpack', n_comps=100)
sc.pl.pca_variance_ratio(bdata, log=True, n_pcs=100)

# %%
sc.external.pp.harmony_integrate(bdata, key = 'sequencing_batch', adjusted_basis='X_pca')
# Out:
# 2022-07-22 12:47:00,636 - harmonypy - INFO - Iteration 1 of 10
# 2022-07-22 12:47:01,031 - harmonypy - INFO - Iteration 2 of 10
# 2022-07-22 12:47:01,304 - harmonypy - INFO - Iteration 3 of 10
# 2022-07-22 12:47:01,519 - harmonypy - INFO - Iteration 4 of 10
# 2022-07-22 12:47:01,737 - harmonypy - INFO - Converged after 4 iterations

# %%
sc.pp.neighbors(bdata, n_neighbors=10, n_pcs = 60)
sc.tl.umap(bdata, min_dist=.3)

# %%
sc.pl.umap(bdata, color=['sequencing_batch', 'sample_id'])

# %%
# sc.tl.leiden(bdata)
sc.pl.umap(bdata, color=['celltype', 'condition'])

# %%
sc.pl.umap(bdata, color = ['Cd19', 'Ms4a1', 'Cd79a', 'Il7r', 'Sox5', 'Cd3d', 'Cd27', 'Gpr183', 'Mki67', 'Ighm', 'Ighd'], color_map = tools.cmp(), ncols = 3)

# %%
sc.tl.rank_genes_groups(bdata, groupby = 'celltype', method = 'wilcoxon')

# %%
sc.pl.rank_genes_groups_dotplot(bdata, n_genes= 5, 
                                min_logfoldchange = 1, 
                                standard_scale = 'var', 
                                color_map = 'viridis', dendrogram = False)

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Cd83', 'Cd86', 'Fcgr2b'],
               'Developing':['Il7r', 'Cd93', 'Rag1', 'Dntt', 'Pax5'],
               'Follicle':['Cxcr5', 'Icosl', 'Gpr183', 'Ccr6'],
               'Germinal centre':['Cd40', 'Bach2', 'Myc', 'Ccnd2', 'Ccnd3', 'Cxcr4', 'Cd38', 'Sox5', 'Mki67',],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3'],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17'],
               'other':['Cxcr3', 'Cd5', 'Cd27', 'Cxcl12', 'Cxcl13'],
               'Follicular T-cell':['Bcl6', 'Pdcd1', 'Cd3e', 'Cd40lg', 'Foxp3']
              }
              , groupby = 'celltype', color_map = 'GnBu', standard_scale = 'var', var_group_rotation = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fee415f451e4> in <module>
# ----> 1 sc.pl.dotplot(bdata,
#       2               {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Cd83', 'Cd86', 'Fcgr2b'],
#       3                'Developing':['Il7r', 'Cd93', 'Rag1', 'Dntt', 'Pax5'],
#       4                'Follicle':['Cxcr5', 'Icosl', 'Gpr183', 'Ccr6'],
#       5                'Naive':['Tcl1a'],
#
# NameError: name 'sc' is not defined

# %%
adata.write_h5ad('h5ad/meninges_integrated.h5ad', compression = 'gzip')

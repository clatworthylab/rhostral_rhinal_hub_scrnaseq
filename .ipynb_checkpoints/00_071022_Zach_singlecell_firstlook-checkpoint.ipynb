# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
sc.logging.print_header()

warnings.filterwarnings('ignore')
os.chdir(os.path.expanduser('/home/jovyan/Zach/scanpy/'))
# Out:
# scanpy==1.7.0 anndata==0.7.5 umap==0.5.1 numpy==1.19.4 scipy==1.5.2 pandas==1.2.2 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 leidenalg==0.8.2

# %%
def bh(pvalues):
    """
    Computes the Benjamini-Hochberg FDR correction.

    Input:
        * pvals - vector of p-values to correct
    """
    n = int(pvalues.shape[0])
    new_pvalues = np.empty(n)
    values = [ (pvalue, i) for i, pvalue in enumerate(pvalues) ]
    values.sort()
    values.reverse()
    new_values = []
    for i, vals in enumerate(values):
        rank = n - i
        pvalue, index = vals
        new_values.append((n/rank) * pvalue)
    for i in range(0, int(n)-1):
        if new_values[i] < new_values[i+1]:
            new_values[i+1] = new_values[i]
    for i, vals in enumerate(values):
        pvalue, index = vals
        new_pvalues[index] = new_values[i]
    return new_pvalues

def scrublet_doublet(self, pval_cutoff=0.1):
    # run Scrublet
    _adata = self.copy()
    scrub = scr.Scrublet(_adata.X)
    doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose=False)
    _adata.obs['scrublet_score'] = doublet_scores
    # overcluster prep. run basic scanpy pipeline
    sc.pp.filter_cells(_adata, min_genes = 0)
    sc.pp.normalize_total(_adata, target_sum = 1e4)
    sc.pp.log1p(_adata)
    sc.pp.highly_variable_genes(_adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
    _adata = _adata[:, _adata.var['highly_variable']]
    sc.pp.scale(_adata, max_value=10)
    sc.tl.pca(_adata, svd_solver='arpack')
    sc.pp.neighbors(_adata, n_neighbors=10, n_pcs=50)
    sc.tl.leiden(_adata)
    for clus in list(np.unique(_adata.obs['leiden']))[0]:
        sc.tl.leiden(_adata, restrict_to=('leiden',[clus]), key_added = 'leiden_R')
    for clus in list(np.unique(_adata.obs['leiden']))[1:]: # weird how the new anndata/scanpy is forcing this
        sc.tl.leiden(_adata, restrict_to=('leiden_R',[clus]), key_added = 'leiden_R')
    # compute the cluster scores - the median of Scrublet scores per overclustered cluster
    for clus in np.unique(_adata.obs['leiden_R']):
        _adata.obs.loc[_adata.obs['leiden_R']==clus, 'scrublet_cluster_score'] = \
            np.median(_adata.obs.loc[_adata.obs['leiden_R']==clus, 'scrublet_score'])
    # now compute doublet p-values. figure out the median and mad (from above-median values) for the distribution
    med = np.median(_adata.obs['scrublet_cluster_score'])
    mask = _adata.obs['scrublet_cluster_score']>med
    mad = np.median(_adata.obs['scrublet_cluster_score'][mask]-med)
    # 1 sided test for catching outliers
    pvals = 1-scipy.stats.norm.cdf(_adata.obs['scrublet_cluster_score'], loc=med, scale=1.4826*mad)
    _adata.obs['scrublet_score_bh_pval'] = bh(pvals)
    # threshold the p-values to get doublet calls.
    _adata.obs['is_doublet'] = _adata.obs['scrublet_score_bh_pval'] < pval_cutoff
    _adata.obs['is_doublet'] = _adata.obs['is_doublet'].astype('category')
    
    # removing columns that probably don't need anymore
    keep = ['scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet']
    for k in keep:
        self.obs[k] = pd.Series(_adata.obs[k])

# %%
# just do naive only and split up each tissue
adata_list = []

samples = ['LN', 'Men']
site_dict = {'LN':'LN', 'Men':'Meninges'}

for s in samples:
    adatax = sc.read_10x_h5('../raw/'+s+'_naive_outs/'+s+'_naive_filtered_feature_bc_matrix.h5')
    adatax.var_names_make_unique()
    adatax.obs['sampleid'] = s + '_naive'
    adatax.obs['site'] = site_dict[s]
    adatax.obs_names = [s +'_naive'+'_' + n for n in adatax.obs_names]
    scrublet_doublet(adatax)
    adata_list.append(adatax)
adata = adata_list[0].concatenate(adata_list[1:], index_unique=None)
adata
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 11118 × 31053
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
pd.crosstab(adata.obs['is_doublet'], adata.obs['sampleid'])
# Out:
# sampleid    LN_naive  Men_naive
# is_doublet
# False           9258       1314
# True             440        106

# %%
# remove doublets
adata = adata[adata.obs['is_doublet'] == False].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 10572 × 31053
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch'
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
# calculate mitochondrial stats
adata.var['mt'] = adata.var_names.str.startswith('mt-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)
# Out:
# ... storing 'sampleid' as categorical
# ... storing 'site' as categorical
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %%
# filter
adata = adata[adata.obs.n_genes_by_counts < 6000, :]
adata = adata[adata.obs.pct_counts_mt < 30, :]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 10288 × 17054
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(adata)

# %%
adata.raw = adata

# %%
adata = adata[:, adata.var.highly_variable]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 10288 × 1969
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca_variance_ratio(adata, log=True, n_pcs = 50)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
sc.tl.leiden(adata)
sc.tl.umap(adata, min_dist=.3)
sc.pl.umap(adata, color=['site', 'leiden'], legend_loc = 'on data', legend_fontoutline = 2)

# %%
sc.tl.rank_genes_groups(adata, groupby = 'leiden', method = 'wilcoxon')
sc.pl.rank_genes_groups_dotplot(adata, n_genes=10, standard_scale = 'var', color_map = 'viridis', min_logfoldchange = 2)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %%
sc.pl.dotplot(adata, ['Cd3e', 'Ncr1', 'Ncam1', 'Il7r', 'Klrc2', 'Trdc', 'Tcrg-C1'], groupby = 'leiden', standard_scale = 'var', color_map = 'Blues')

# %%
sc.pl.dotplot(adata, ['Cd19', 'Ms4a1', 'Cd38', 'Bach2', 'Dntt', 'Il7r'], groupby = 'leiden', standard_scale = 'var', color_map = 'Blues')

# %%
sc.tl.leiden(adata, restrict_to = ('leiden', ['16']), key_added = 'leiden-2', resolution = .3)
sc.tl.leiden(adata, restrict_to = ('leiden-2', ['7']), key_added = 'leiden-2', resolution = .3)
sc.tl.leiden(adata, restrict_to = ('leiden-2', ['5']), key_added = 'leiden-2', resolution = .3)
sc.tl.leiden(adata, restrict_to = ('leiden-2', ['11']), key_added = 'leiden-2', resolution = .5)
# sc.tl.leiden(adata, restrict_to = ('leiden-2', ['10']), key_added = 'leiden-2', resolution = .3)

# %%
sc.pl.umap(adata, color = ['leiden-2'], legend_loc = 'on data', legend_fontoutline = 2)

# %%
sc.pl.dotplot(adata, ['Trbc1', 'Cd8a', 'Trac', 'Il7r', 'Klrb1c', 'Jchain', 'Mzb1', 'Bach2', 'Ms4a1', 'Cd79a', 'Il7r', 'Ccr7', 'Sell', 'Cd44', 'Cd3e', 'Bcl6', 'Izumo1r', 'Cxcr5', 'Pdcd1', 'Cd4', 'Cd8b1', 'Foxp3', 'Cd69', 'Itgae', 'Xcr1', 'Clec9a', 'Clec10a', 'Fcgr3', 'Fcgr2b', 'C1qa','Tmem119', 'Cx3cr1', 'Adgre1', 'Itgam', 'H2-Ab1', 'Aldh1l1', 'Slc1a3', 'Enpp3', 'Kit', 'Cebpb', 'Ly6c2', 'Ccr2', 'Eomes', 'Tox', 'Igfbp2', 'Adgre1', 'Trdc', 'Tcrg-C1', 'Rora', 'Rorc', 'Cd27'], groupby = 'leiden-2', standard_scale = 'var', color_map = 'viridis')

# %%
sc.tl.rank_genes_groups(adata, groupby = 'leiden-2', method = 'wilcoxon')
sc.tl.dendrogram(adata, groupby = 'leiden-2')
sc.pl.rank_genes_groups_dotplot(adata, n_genes=10, standard_scale = 'var', color_map = 'Blues', min_logfoldchange = 2)

# %%
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
adata_no_knn = adata.raw.to_adata().copy()
for x in adata_no_knn.obs:
    if adata_no_knn.obs[x].dtype.name == 'category':
        adata_no_knn.obs[x] = adata_no_knn.obs[x].astype('object')
adata_no_knn.obsp = None
adata_no_knn.uns.pop("neighbors")
adata_no_knn
# Out:
# AnnData object with n_obs × n_vars = 10288 × 17054
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'leiden-2', 'initial_clustering'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dendrogram_leiden', 'hvg', 'leiden', 'leiden_colors', 'pca', 'rank_genes_groups', 'site_colors', 'umap', 'dendrogram_leiden-2', 'initial_clustering_colors', 'leiden-2_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
# %%R -i adata_no_knn
# logcounts(adata_no_knn) = assays(adata_no_knn)[['X']]
# saveRDS(adata_no_knn, 'h5ad/adata_tmp.RDS')

# %% [markdown]
# ```R
# library(SingleR)
# library(BiocParallel)
# registered()
#
# ref = ImmGenData()
# # subset to just B cells
#
# sce <- readRDS('h5ad/adata_tmp.RDS')
# pred.main <- SingleR(test=sce, ref=ref, labels=ref$label.main, de.method="wilcox", clusters = sce$leiden.2, BPPARAM = MulticoreParam(workers = 3, progressbar = TRUE))
#
# # for B cells
# # ref2 = ref[, ref$label.main %in% c('B cells', 'B cells, pro')]
# # sce <- sce[,sce$leiden.2 %in% c('0', '3', '7,0', '7,1', '9', '16,0', '16,1', '16,2', '16,3')]
# pred.fine <- SingleR(test=sce, ref=ref2, labels=ref2$label.fine, de.method="wilcox", clusters = sce$leiden.2, BPPARAM = MulticoreParam(workers = 3, progressbar = TRUE))
# ```

# %%
sc.pl.dotplot(adata, 
              {'Follicle':['Cxcr5', 'Icosl'],
               'Germinal centre':['Bach2', 'Aicda', 'Mki67', 'Ccnd1', 'Ccnd3', 'Bcl6', 'Cxcr4', 'Cd83', 'Cd86', 'Fcgr2b', 'Ccnd1', 'Pdcd1', 'Ebi3'],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1'],
               'CD markers':['Cd5', 'Cd9', 'Mme', 'Cd27', 'Cd19', 'Ms4a1', 'Cr2', 'Cd22', 'Sdc1', 'Cd38'],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3'],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17']}
              , groupby = 'leiden-2', color_map = 'GnBu', standard_scale = 'var', dot_max=.7, var_group_rotation = 0)

# %%
newdict = {'0':'B',
'1':'CD8T',
'2':'CD4T',
'3':'B',
'4':'CD8T',
'5,0':'CD8T',
'5,1':'CD4T',
'6':'Treg',
'7,0':'B',
'7,1':'Plasmablast',
'8':'ILC1',
'9':'B',
'10':'CD8T',
'11,0':'CD8T',
'11,1':'CD8T',
'11,2':'CD8T',
'11,3':'CD8T',
'11,4':'CD4T',
'12':'Neutrophil',
'13':'gdT',
'14':'ILC2',
'15':'NK',
'16,0':'GC_B',
'16,1':'GC_B-T_doublet',
'16,2':'GC_B',
'16,3':'GC_B',
'17':'Microglia',
'18':'MNP',
'19':'IFN_B_T_ILC',
'20':'Erythrocyte',
'21':'pDC',
'22':'mDC',
'23':'Mast_cell',
'24':'Olfactory_cell',}
adata.obs['initial_clustering'] = [newdict[x] for x in adata.obs['leiden-2']]

# %%
sc.pl.umap(adata, color = ['initial_clustering', 'site'], ncols = 1)
# Out:
# ... storing 'initial_clustering' as categorical

# %%
adata.obs['initial_clustering'].cat.categories
# Out:
# Index(['B', 'CD4T', 'CD8T', 'Erythrocyte', 'GC_B', 'GC_B-T_doublet',
#        'IFN_B_T_ILC', 'ILC1', 'ILC2', 'MNP', 'Mast_cell', 'Microglia', 'NK',
#        'Neutrophil', 'Olfactory_cell', 'Plasmablast', 'Treg', 'gdT', 'mDC',
#        'pDC'],
#       dtype='object')

# %%
adata.obs['initial_clustering'] = adata.obs['initial_clustering'].cat.reorder_categories(['B','GC_B','Plasmablast','GC_B-T_doublet','CD4T','CD8T','Treg','gdT','ILC1','ILC2','NK','IFN_B_T_ILC','Neutrophil','Mast_cell','Microglia','MNP','mDC','pDC','Erythrocyte','Olfactory_cell'])

# %%
sc.pl.umap(adata, color = 'initial_clustering', palette = [
    '#17becf', # B
    '#1f77b4', # GC_B
    '#253494', # Plasmablast
    '#e8602a', # GC_B-T_doublet
    '#f7c223', # CD4T
    '#810f7c', # CD8T
    '#2ca02c', # Treg
    '#99d8c9', # gdT
    '#aec7e8', # ILC1
    '#d7b5d8', # ILC2
    '#df65b0', # NK
    '#e7e7e7', # IFN_B_T_ILC
    '#faa7ad', # Neutrophil
    '#d40d1a', # Mast_cell
    '#703d91', # Microglia
    '#de4bdb', # MNP
    '#ab92f7', # mDC
    '#fdbe85', # pDC
    '#4e5451', # Erythrocyte
    '#a39b98', # Olfactory_cell
])

# %%
sc.pl.umap(adata, color = 'site')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10288 × 1969
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'leiden-2', 'initial_clustering'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_leiden', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'site_colors', 'umap', 'dendrogram_leiden-2', 'initial_clustering_colors', 'leiden-2_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.write('h5ad/adata_tmp.h5ad', compression = 'gzip')

# %%
# subset to B cells
bdata = adata[adata.obs['initial_clustering'].isin(['B', 'GC_B', 'Plasmablast', 'GC_B-T_doublet'])].copy()
bdata
# Out:
# AnnData object with n_obs × n_vars = 3712 × 1969
#     obs: 'sampleid', 'site', 'scrublet_cluster_score', 'scrublet_score_bh_pval', 'is_doublet', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'leiden-2', 'initial_clustering'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_leiden', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'site_colors', 'umap', 'dendrogram_leiden-2', 'initial_clustering_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(bdata, color = 'initial_clustering', legend_loc = 'on data')

# %%
sc.pl.umap(bdata, color = 'site')

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Cd83', 'Cd86', 'Fcgr2b'],
               'Follicle':['Cxcr5', 'Icosl'],
               'Germinal centre':['Bcl6', 'Bach2', 'Ccnd3', 'Cxcr4','Cd38',  'Mki67', 'Ccnd1','Aicda',],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3'],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17'],
               'other':['Pdcd1', 'Cxcr3', 'Cd5', 'Cd27', 'Cxcl12']}
              , groupby = 'initial_clustering', color_map = 'GnBu', standard_scale = 'var', dot_max=.7, var_group_rotation = 0)

# %%
bdata.obs['clust_group'] = [b +'_' +a for a,b in zip(bdata.obs['site'], bdata.obs['initial_clustering'])]

# %%
sc.pl.dotplot(bdata, 
              {'General':[ 'Cd19', 'Ms4a1',  'Cr2', 'Cd22', 'Cd83', 'Cd86', 'Fcgr2b'],
               'Follicle':['Cxcr5', 'Icosl'],
               'Germinal centre':['Bcl6', 'Bach2', 'Ccnd3', 'Cxcr4','Cd38',  'Mki67', 'Ccnd1','Aicda',],
               'Plasmablast':['Jchain','Mzb1', 'Bcl2', 'Rela', 'Irf4', 'Prdm1', 'Sdc1', 'Cd9',],
               'Immunogobulins':['Ighm', 'Ighd', 'Igha', 'Ighg1','Ighg2b','Ighg2c', 'Ighg3'],
               'BAFF-receptors':['Tnfrsf13b', 'Tnfrsf13c', 'Tnfrsf17'],
               'other':['Pdcd1', 'Cxcr3', 'Cd5', 'Cd27', 'Cxcl12']}
              , groupby = 'clust_group', color_map = 'GnBu', standard_scale = 'var', dot_max=.7, var_group_rotation = 0)
# Out:
# ... storing 'clust_group' as categorical

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import dandelion as ddl
import os
import tools

sc.logging.print_header()

os.chdir(os.path.expanduser('/home/jovyan/Zach/scanpy/'))
adata = sc.read_h5ad('h5ad/combined_raw.h5ad')
adata
# Out:
# scanpy==1.8.2 anndata==0.7.5 umap==0.5.1 numpy==1.19.4 scipy==1.5.2 pandas==1.2.3 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 leidenalg==0.8.2 pynndescent==0.5.2
# AnnData object with n_obs × n_vars = 53796 × 29836
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna'
#     uns: 'filter_rna_colors'
#     layers: 'counts'

# %%
# basic filter
sc.pp.filter_cells(adata, min_genes = 200)
sc.pp.filter_cells(adata, max_genes = 10000)
# remove high mitochondrial
adata = adata[adata.obs['gmm_pct_count_clusters_keep']].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 45774 × 29836
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna'
#     uns: 'filter_rna_colors'
#     layers: 'counts'

# %%
sc.pp.filter_genes(adata, min_cells=3)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
# split to condition
adata = adata[(adata.obs['site'] == 'LN')].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 33843 × 21680
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna'
#     var: 'n_cells'
#     uns: 'filter_rna_colors', 'log1p'
#     layers: 'counts'

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
sc.pl.highly_variable_genes(adata)

# %%
adata.raw = adata

# %%
adata = adata[:, adata.var.highly_variable].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 33843 × 1903
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'filter_rna_colors', 'log1p', 'hvg'
#     layers: 'counts'

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack', n_comps=100)
sc.pl.pca_variance_ratio(adata, log=True, n_pcs=100)

# %%
sc.external.pp.harmony_integrate(adata, key = 'sequencing_batch', adjusted_basis='X_pca')
# Out:
# 2022-07-18 08:58:57,581 - harmonypy - INFO - Iteration 1 of 10
# 2022-07-18 09:01:01,397 - harmonypy - INFO - Iteration 2 of 10
# 2022-07-18 09:03:07,598 - harmonypy - INFO - Converged after 2 iterations

# %%
sc.pl.pca_variance_ratio(adata, log=True, n_pcs=100)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs = 30)
sc.tl.leiden(adata)
sc.tl.umap(adata, min_dist=.3)

# %%
sc.pl.umap(adata, color=['sample_id', 'leiden'])

# %%
sc.pl.umap(adata, color = ['is_doublet'])

# %%
sc.pl.umap(adata, color = ['Cd19', 'Ms4a1', 'Il7r', 'Sox5',  'Aicda', 'Mki67', 'Ighg2b', 'Ighg3', 'Igha'], color_map = tools.cmp(), ncols = 3, size = 10)

# %%
gs = pd.read_csv('../mouse_mouse_2010_victoria_B_cell_genesets.txt', sep = '\t')
for x in gs:
    sc.tl.score_genes(adata, [y for y in gs[x] if pd.notnull(y)], score_name = x, use_raw = True)
sc.pl.umap(adata, color = gs.columns, color_map = 'viridis', ncols = 3, size = 10)
# Out:
# WARNING: genes are not in var_names and ignored: ['Hpcal4', 'Htr1a', 'Itprip', 'Mideas', 'Nlrp9a', 'Nlrp9b', 'Npy5r', 'Potefam3e', 'Potegl', 'Spink5']
# WARNING: genes are not in var_names and ignored: ['Cplane2', 'Dele1', 'Dnaaf10', 'H2bc7', 'Otulinl', 'Prxl2b', 'Tafazzin']
# WARNING: genes are not in var_names and ignored: ['Adgrf1', 'Gcn1', 'Htr1a', 'Iftap', 'Gm11555', 'Krtap4-7', 'Oprk1', 'Slc28a2b']
# WARNING: genes are not in var_names and ignored: ['4930522H14Rik', 'C8b', 'Cacng2', 'Cfap20dc', 'Cnfn', 'Cyp4a31', 'Dmbx1', 'Insyn2a', 'Gm10024', 'Gm10142', 'Ndp', 'Prss21', 'Slc22a19', 'Slc22a26', 'Slc22a30', 'Tbx5']
# WARNING: genes are not in var_names and ignored: ['Ccnq', 'Dnaaf9', 'Krtap8-1', 'Otc', 'Psme3ip1', 'Tafazzin', 'Tasor2', 'Tent5c', 'Uts2r']
# WARNING: genes are not in var_names and ignored: ['Itprip', 'Olfr1356', 'Ugt2b34']

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 33843 × 1903
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'is_doublet', 'filter_rna', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'filter_rna_colors', 'log1p', 'hvg', 'pca', 'neighbors', 'leiden', 'umap', 'sample_id_colors', 'leiden_colors', 'is_doublet_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'

# %%
adata.write('h5ad/ln_integrated.h5ad', compression = 'gzip')

# %%
# rough annotation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import os
import tools

sc.logging.print_header()

os.chdir(os.path.expanduser('/home/jovyan/Zach/scanpy/'))
adata = sc.read_h5ad('h5ad/meninges_naive_integrated.h5ad')
adata
# Out:
# scanpy==1.8.2 anndata==0.7.5 umap==0.5.1 numpy==1.19.4 scipy==1.5.2 pandas==1.2.3 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 leidenalg==0.8.2 pynndescent==0.5.2
# AnnData object with n_obs × n_vars = 5409 × 4062
#     obs: 'sample_id', 'condition', 'site', 'sequencing_batch', 'scrublet_score', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'is_doublet', 'filter_rna', 'leiden', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_DARK_ZONE_VS_NAIVE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_DARK_ZONE_BCELL_UP', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_DN', 'GSE23925_LIGHT_ZONE_VS_NAIVE_BCELL_UP'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'filter_rna_colors', 'hvg', 'is_doublet_colors', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'sample_id_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.tl.leiden(adata, resolution = .8)
sc.pl.umap(adata, color=['leiden', 'is_doublet'], legend_loc = 'on data', legend_fontoutline = 2)

# %%
sc.tl.leiden(adata, resolution = .2, restrict_to = ('leiden', ['21']))
# sc.tl.leiden(adata, resolution = .3, restrict_to = ('leiden_R', ['19']))
sc.pl.umap(adata, color=['leiden_R', 'is_doublet'], legend_loc = 'on data', legend_fontoutline = 2)

# %%
pd.crosstab(adata.obs['leiden_R'], adata.obs['is_doublet']).apply(lambda r: r/r.sum() * 100, axis = 1).plot.bar(stacked=True, figsize = (10,4))
plt.legend(bbox_to_anchor=(1,.5), loc = 'center left', frameon = False)

# %%
sc.pl.dotplot(adata, 
              {'nkcell':['Ncr1', 'Ncam1', 'Klrc1',],
               'ilc':['Il7r', 'Rorc', 'Rora',],
               'tcell':['Cd3d', 'Cd4', 'Cd8b1', 'Foxp3', 'Trdc', 'Tcrg-C1',],
               'bcell':['Cd19', 'Ms4a1', 'Mzb1'],
               'monocyte':['Ly6c2', 'Ccr2'],
               'MNP':['Elane', 'S100a8', 'C1qc', 'H2-Ab1'],
               'microglia':['Itgam', 'Cx3cr1', 'Adgre1', 'Mertk', 'P2ry12', 'Fcrls', 'Tmem119', 'Olfml3', 'Hexb', 'Tgfbr1'],
               'DC':['Itgax', 'Xcr1', 'Itgae', 'Batf3'],
               'pDC':['Irf7', 'Kit', 'Siglech'],
               'endothelial':['Pecam1', 'Flt1', 'Ptprb'],
               'stromal':['Lyve1', 'Dcn', 'Vim'],
               'neuronal':['Tubb3'],
               'proliferating':['Mki67', 'Junb', 'Fos'],
              }
              , groupby = 'leiden_R', color_map = 'GnBu', standard_scale = 'var', dot_max=.7, var_group_rotation = 0)

# %%
sc.tl.rank_genes_groups(adata, groupby = 'leiden_R')
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes= 5, min_logfoldchange = 2, standard_scale = 'var', color_map = 'viridis', dendrogram = False)
